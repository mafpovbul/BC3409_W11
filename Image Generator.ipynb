# %%
import replicate
import os

os.environ["REPLICATE_API_TOKEN"]="r8_Gxanu3oPoqGsCJfry4o9OEe8858SQRI1iWYE8"

inputs = input("Enter : ")

r = replicate.run(
    "stability-ai/stable-diffusion:db21e45d3f7023abc2a46ee38a23973f6dce16bb082a930b0c49861f96d1e5bf",
    input={
        "prompt": inputs,
}
)
print(r)

import requests
from PIL import Image
r = Image.open(requests.get(r[0], stream=True).raw)
r
# Out:
# Enter : dog
# ['https://replicate.delivery/pbxt/ppZOuNDDoUbTIhXMCh0BDxGEkqlMPoF9wFkeNaTEGNywVYTJA/out-0.png']
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=768x768 at 0x1F8917F3760>
